# %% [markdown]
# # Loops Practice self :-

# %%
# while condition :-  # ( while ka matlab hota hai jab tack)

# %% [markdown]
# brack:-

# %%
a = 0
while a<10:
    print(a)
    if a==5:
        break
    a+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
name = ["rohan","mohan","karan","manav","gourav","rahul","rash"] # kabi bhi len 
i = 0
while i<len(name):
    print(name[i])
    if name[i] == "manav":
        break
    i+=1
# Out:
# rohan
# mohan
# karan
# manav

# %%
for i in range (10):
    print(i)
    if i == 5:
        break
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
a = [15,37,19,14,17,13]
for i in a:
    if i%2==0:
        break
    print(i)
# Out:
# 15
# 37
# 19

# %%
num = int(input("Enter Number: "))
while if 5
    if
# Out:
# Enter Number:  3

# %%
I = []
while

# %%
for i in range(10):
    if i ==5:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
a = ["rohan","mohan","mohit","yash","karan","rahul","rohit"]
for i in a:
    if i=="mohit" or i== "karan":
        f
while i<len(a):
    if a[i] in ["mohit","karan"]
        print(a[i])
        count+=1
    i+=1
print("name: ",count)
# Out:
#   Cell In[17], line 5
#     if a[i] in ["mohit","karan"]
#                                 ^
# SyntaxError: expected ':'

# %%
first = ["harsh" , "rohan", "mohan" , "keshav"]
last = ["khanna" , "shrama" ,"malotra" ,"bhardwaj"]
full = []
for i,j in zip(first , last):
    full.append(i+"  "+j)

# %%
print(full)
# Out:
# ['harsh  khanna', 'rohan  shrama', 'mohan  malotra', 'keshav  bhardwaj']

# %%
student = ["rohan", "mohit" , "yash" , "rahul"]
english = [75, 88, 93, 44]
maths = [81, 83,94,59]
science = [75,88,86,91]
marks = []
for i , j , k , l in zip(student , english,maths,science ):
    marks.append(f"{i} : {j+k+l}")
print(marks)
# Out:
# ['rohan : 231', 'mohit : 259', 'yash : 273', 'rahul : 194']

# %%
a = ["rohgan" , "mohan" , "karan" , "manav"]
for i, j in enumerate(a):
    print(i , j)
# Out:
# 0 rohgan
# 1 mohan
# 2 karan
# 3 manav

# %%
for i, j in enumerate(range(15, 30)):
    print(i,j)
# Out:
# 0 15
# 1 16
# 2 17
# 3 18
# 4 19
# 5 20
# 6 21
# 7 22
# 8 23
# 9 24
# 10 25
# 11 26
# 12 27
# 13 28
# 14 29

# %%
name = ["rahon,","mohan","yash"]
b = [i for i in name]
print(b)
# Out:
# ['rahon,', 'mohan', 'yash']

# %%
for i in name:
    print(i)
# Out:
# rahon,
# mohan
# yash

# %%
num = [1 to 30]
m2 = [divisible by 2 from num]
m3 = [by 3]
m4 = [by 4]
for i in num <= 1:
    print(num)
    i+= 1
print(num)
# Out:
#   Cell In[9], line 1
#     num = [1 to 30]
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
num = [i for i in range(30)]
m2 =

# %%
name = ["gaurav","aditya","yash","raj"]
lon_name = [5<=]
short_name =[5<]
print(long_name)
print()

# %%
name = ["rohan","mohit","yash","rahul"]
name = [i.tital() for i in name]
print(name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 name = ["rohan","mohit","yash","rahul"]
# ----> 2 name = [i.tital() for i in name]
#       3 print(name)
#
# AttributeError: 'str' object has no attribute 'tital'

# %%
name ["rohan","aditya","aarav","mohit","yeas","aryan"]
b = [i for i in name if i [0] .loewr()=="a"]
print(name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 name ["rohan","aditya","aarav","mohit","yeas","aryan"]
#       2 b = [i for i in name if i [0] .loewr()=="a"]
#       3 print(name)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
states = ["Even" if i%2==0 else "odd"for i in a]
print(states)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 states = ["Even" if i%2==0 else "odd"for i in a]
#       2 print(states)
#
# TypeError: not all arguments converted during string formatting

# %%
num = [-7 , 15 , 4 , -18 , 3 ,-1]
num = ["positive"if i > 0 else "negative"for i in num]
print(num)
# Out:
# ['negative', 'positive', 'positive', 'negative', 'positive', 'negative']

# %%
num = [1,2,3,4,5]
result = [1**2 if i%2!=0 else i for i in num]
print(result)
# Out:
# [1, 2, 1, 4, 1]

# %%
num = ["ROHAN","Aditya","aarav","mohit","yash","arya"]
b = [i.upper () if i[0].lower() =="a" else i.lower() for i in name]
print(b)
# Out:
# ['rohan', 'mohit', 'yash', 'rahul']
