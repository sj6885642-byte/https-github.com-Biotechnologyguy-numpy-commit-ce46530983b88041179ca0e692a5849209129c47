# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
pd.__version__
# Out:
# '3.0.0'

# %%
di = {
    "ID":[101,102,103,104,105,106,107,108,109,110],
    "Name":["Rohan","mohit","yash","keshav","karan","rahul","aryan","arjun","aditya","chandan"],
    "Age":[27,29,37,34,39,24,26,31,28,33,],
    "Dept":["IT","Sales","HR","IT","Sales","Operations","IT","Sales","HR","Operations"],
    "Salary":[72000,43000,32000,55000,49000,79000,124000,91000,67000,70000]
}

# %%
pd.DataFrame(di)
# Out:
#     ID     Name  Age        Dept  Salary
# 0  101    Rohan   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  Operations   70000

# %%
df = pd.DataFrame(di)

# %%
df
# Out:
#     ID     Name  Age        Dept  Salary
# 0  101    Rohan   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  Operations   70000

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
type(df["Name"]).dtype

# %%
df["Salary"]
# Out:
# 0     72000
# 1     43000
# 2     32000
# 3     55000
# 4     49000
# 5     79000
# 6    124000
# 7     91000
# 8     67000
# 9     70000
# Name: Salary, dtype: int64

# %%
df["Age"].dtype
# Out:
# dtype('int64')

# %%
type(df["Age"]).dtype

# %%
type(df["Salary"]).dtype

# %%
df["Salary"].dtype
# Out:
# dtype('int64')

# %%
# iloc Method ------ df .iloc(row_index , col_index)
df.iloc[6,1]
# Out:
# 'aryan'

# %%
df.iloc[3,4]
# Out:
# np.int64(55000)

# %%
# loc Method ---- df.loc(row_index , col_name)
df.iloc[6, 1]
# Out:
# 'aryan'

# %%
#iloc slicing
df.iloc[4 , :]
# Out:
# ID          105
# Name      karan
# Age          39
# Dept      Sales
# Salary    49000
# Name: 4, dtype: object

# %%
di = {
    "ID":[101,102,103,104,105,106,107,108,109,110],
    "Name":["Rohan","mohit","yash","keshav","karan","rahul","aryan","arjun","aditya","chandan"],
    "Age":[27,29,37,34,39,24,26,31,28,33,],
    "Dept":["IT","Sales","HR","IT","Sales","Operations","IT","Sales","HR","Operations"],
    "Salary":[72000,43000,32000,55000,49000,79000,124000,91000,67000,70000]
}

# %%
df = pd.DataFrame(di)
df
# Out:
#     ID     Name  Age        Dept  Salary
# 0  101    Rohan   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  Operations   70000

# %%
# Head Method ---df.Head()
df.head(2)
# Out:
#     ID   Name  Age   Dept  Salary
# 0  101  Rohan   27     IT   72000
# 1  102  mohit   29  Sales   43000

# %%
# Tail Method ---df.tail()
df.tail(2)
# Out:
#     ID     Name  Age        Dept  Salary
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  Operations   70000

# %%
# D3scribe Method -- df.Describe()
df.describe()
# Out:
#               ID        Age         Salary
# count   10.00000  10.000000      10.000000
# mean   105.50000  30.800000   68200.000000
# std      3.02765   4.894441   26368.331174
# min    101.00000  24.000000   32000.000000
# 25%    103.25000  27.250000   50500.000000
# 50%    105.50000  30.000000   68500.000000
# 75%    107.75000  33.750000   77250.000000
# max    110.00000  39.000000  124000.000000

# %%
# astype method --- df{col},astype(type)
df["ID"] = df["ID"].astype(str)

# %%
# unique Method ---df["col"] .unique()
df["Dept"].unique()
# Out:
# <ArrowStringArray>
# ['IT', 'Sales', 'HR', 'Operations']
# Length: 4, dtype: str

# %%
df.iloc[0 , 1] ="Rohit"

# %%
df
# Out:
#     ID     Name  Age        Dept  Salary
# 0  101    Rohit   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  Operations   70000

# %%
df.loc[9 , "Dept"] = "POERATIONS"

# %%
df
# Out:
#     ID     Name  Age        Dept  Salary
# 0  101    Rohit   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  POERATIONS   70000

# %%
df["Dept"].unique()
# Out:
# <ArrowStringArray>
# ['IT', 'Sales', 'HR', 'Operations', 'POERATIONS']
# Length: 5, dtype: str

# %%
# Valie_Counts Method ----- df[col].Value_Counts
df["Dept"].value_counts()
# Out:
# Dept
# IT            3
# Sales         3
# HR            2
# Operations    1
# POERATIONS    1
# Name: count, dtype: int64

# %%
# Replace method
df["Dept"].replace("OPERATIONS","Support",)
# Out:
# 0            IT
# 1         Sales
# 2            HR
# 3            IT
# 4         Sales
# 5    Operations
# 6            IT
# 7         Sales
# 8            HR
# 9    POERATIONS
# Name: Dept, dtype: str

# %%
df["Dept"].replace({"support" : "Operation" , "IT" : "Tech" , "SALES" : "Sales"})
# Out:
# 0          Tech
# 1         Sales
# 2            HR
# 3          Tech
# 4         Sales
# 5    Operations
# 6          Tech
# 7         Sales
# 8            HR
# 9    POERATIONS
# Name: Dept, dtype: str

# %%
df
# Out:
#     ID     Name  Age        Dept  Salary
# 0  101    Rohit   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  POERATIONS   70000

# %%
# new  Columns
df["city"] = ["Delhi" , "Mumbai"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 # new  Columns
# ----> 2 df["city"] = ["Delhi" , "Mumbai"]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4672, in DataFrame.__setitem__(self, key, value)
#    4669     self._setitem_array([key], value)
#    4670 else:
#    4671     # set column
# -> 4672     self._set_item(key, value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4872, in DataFrame._set_item(self, key, value)
#    4862 def _set_item(self, key, value) -> None:
#    4863     """
#    4864     Add series to DataFrame in specified column.
#    4865
#    (...)   4870     ensure homogeneity.
#    4871     """
# -> 4872     value, refs = self._sanitize_column(value)
#    4874     if (
#    4875         key in self.columns
#    4876         and value.ndim == 1
# ...

# %%
df
# Out:
#     ID     Name  Age        Dept  Salary
# 0  101    Rohit   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  POERATIONS   70000

# %%
# Renam Columns
df.column = ["Id" , "Full Name" , "Age" , "Dept" , "Salary" , "City"]

# %%
df
# Out:
#     ID     Name  Age        Dept  Salary
# 0  101    Rohit   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  POERATIONS   70000

# %%
l = []
for i in df.colimns:
    if i == "Full Name":
        l.append("Name")
    else:
        l
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12960\1325307374.py in ?()
#       1 l = []
# ----> 2 for i in df.colimns:
#       3     if i == "Full Name":
#       4         l.append("Name")
#       5     else:
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'colimns'

# %%
df = df[["Id" , "Name" , "City" , "Age" , "Dept" , "Salary"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df = df[["Id" , "Name" , "City" , "Age" , "Dept" , "Salary"]]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
# ...

# %%
df

# %%
df["Country"] = ["india" , for i in range(10)]
df["Company"] = ["ABC Pvt. Ltd." for i in range(10)]
# Out:
#   Cell In[62], line 1
#     df["Country"] = ["india" , for i in range(10)]
#                      ^
# SyntaxError: did you forget parentheses around the comprehension target?

# %%
df.drop(Columns = ["Country" , "Company"] , Inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df.drop(Columns = ["Country" , "Company"] , Inplace = True)
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'Columns'. Did you mean 'columns'?

# %%
df
# Out:
#     ID     Name  Age        Dept  Salary
# 0  101    Rohit   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  POERATIONS   70000

# %% [markdown]
# # Class third

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "ID":[101,102,103,104,105,106,107,108,109,110],
    "Name":["Rohan","mohit","yash","keshav","karan","rahul","aryan","arjun","aditya","chandan"],
    "Age":[27,29,37,34,39,24,26,31,28,33,],
    "Dept":["IT","Sales","HR","IT","Sales","Operations","IT","Sales","HR","Operations"],
    "Salary":[72000,43000,32000,55000,49000,79000,124000,91000,67000,70000]
})

# %%
pd.DataFrame(di)
# Out:
#     ID     Name  Age        Dept  Salary
# 0  101    Rohan   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  Operations   70000

# %%
l = []
for i in df.columns:
    l.append(i.title())

# %%
print(l)
# Out:
# ['Id', 'Name', 'Age', 'Dept', 'Salary']

# %%
df.columns = l

# %%
df
# Out:
#     Id     Name  Age        Dept  Salary
# 0  101    Rohan   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  Operations   70000

# %%
emp_id , emp_name , emp_age , emp_dept , emp_salary , emp_city
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 emp_id , emp_name , emp_age , emp_dept , emp_salary , emp_city
#
# NameError: name 'emp_id' is not defined

# %%
l =[]
for i in df.columns:
    l.append("emp_"+ i.lower())

# %%
print(l)
# Out:
# ['emp_id', 'emp_name', 'emp_age', 'emp_dept', 'emp_salary']

# %%
df.columns = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 df.columns = 1
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:6220, in NDFrame.__setattr__(self, name, value)
#    6218 try:
#    6219     object.__getattribute__(self, name)
# -> 6220     return object.__setattr__(self, name, value)
#    6221 except AttributeError:
#    6222     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:765, in NDFrame._set_axis(self, axis, labels)
#     759 @final
#     760 def _set_axis(self, axis: AxisInt, labels: AnyArrayLike | list) -> None:
#     761     """
#     762     This is called from the cython code when we set the `index` attribute
#     763     directly, e.g. `series.index = [1, 2, 3]`.
# ...

# %%
df
# Out:
#     Id     Name  Age        Dept  Salary
# 0  101    Rohan   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  Operations   70000

# %%
l = []
for i in df["end_name"]:
    l.append(i.tital())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'end_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 2
#       1 l = []
# ...

# %%
print(l)
# Out:
# []

# %%
df["emp_name"] = l
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df["emp_name"] = l
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4672, in DataFrame.__setitem__(self, key, value)
#    4669     self._setitem_array([key], value)
#    4670 else:
#    4671     # set column
# -> 4672     self._set_item(key, value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4872, in DataFrame._set_item(self, key, value)
#    4862 def _set_item(self, key, value) -> None:
#    4863     """
#    4864     Add series to DataFrame in specified column.
#    4865
#    (...)   4870     ensure homogeneity.
#    4871     """
# -> 4872     value, refs = self._sanitize_column(value)
#    4874     if (
#    4875         key in self.columns
#    4876         and value.ndim == 1
# ...

# %%
df
# Out:
#     Id     Name  Age        Dept  Salary
# 0  101    Rohan   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  Operations   70000

# %%
l = []
for i in df["end_name"]:
    l.append(i.tital())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'end_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 2
#       1 l = []
# ...

# %%
a = "emp_name"
print(a.repalce("emp_", "").title())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[80], line 2
#       1 a = "emp_name"
# ----> 2 print(a.repalce("emp_", "").title())
#
# AttributeError: 'str' object has no attribute 'repalce'

# %%
print(l)
# Out:
# []

# %%
df.columns = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 df.columns = 1
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:6220, in NDFrame.__setattr__(self, name, value)
#    6218 try:
#    6219     object.__getattribute__(self, name)
# -> 6220     return object.__setattr__(self, name, value)
#    6221 except AttributeError:
#    6222     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:765, in NDFrame._set_axis(self, axis, labels)
#     759 @final
#     760 def _set_axis(self, axis: AxisInt, labels: AnyArrayLike | list) -> None:
#     761     """
#     762     This is called from the cython code when we set the `index` attribute
#     763     directly, e.g. `series.index = [1, 2, 3]`.
# ...

# %%
df
# Out:
#     Id     Name  Age        Dept  Salary
# 0  101    Rohan   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  Operations   70000

# %%
a = "emp_name"
print(a.repalce("emp_","72k").title())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 2
#       1 a = "emp_name"
# ----> 2 print(a.repalce("emp_","72k").title())
#
# AttributeError: 'str' object has no attribute 'repalce'

# %%
print(l)
# Out:
# []

# %%
df.colunmns = 1

# %%
df
# Out:
#     Id     Name  Age        Dept  Salary
# 0  101    Rohan   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  Operations   70000

# %%
a  = 72000
print(f"{a/1000}k")
# Out:
# 72.0k

# %%
a = 72000
a = str(a/1000)+"k"
print(a)
# Out:
# 72.0k

# %%
l = []
for i in df["salary"]:
    l.append(str(i/1000)+"k")
print(l)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'salary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 2
#       1 l = []
# ...

# %%
df["salary"] = l
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df["salary"] = l
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4672, in DataFrame.__setitem__(self, key, value)
#    4669     self._setitem_array([key], value)
#    4670 else:
#    4671     # set column
# -> 4672     self._set_item(key, value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4872, in DataFrame._set_item(self, key, value)
#    4862 def _set_item(self, key, value) -> None:
#    4863     """
#    4864     Add series to DataFrame in specified column.
#    4865
#    (...)   4870     ensure homogeneity.
#    4871     """
# -> 4872     value, refs = self._sanitize_column(value)
#    4874     if (
#    4875         key in self.columns
#    4876         and value.ndim == 1
# ...

# %%
df
# Out:
#     Id     Name  Age        Dept  Salary
# 0  101    Rohan   27          IT   72000
# 1  102    mohit   29       Sales   43000
# 2  103     yash   37          HR   32000
# 3  104   keshav   34          IT   55000
# 4  105    karan   39       Sales   49000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  Operations   70000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      10 non-null     int64
#  1   Name    10 non-null     str
#  2   Age     10 non-null     int64
#  3   Dept    10 non-null     str
#  4   Salary  10 non-null     int64
# dtypes: int64(3), str(2)
# memory usage: 630.0 bytes

# %%
a = "72.0k"
print(float(a.replace("k" , ""))*1000)
# Out:
# 72000.0

# %%
l =[]
for i in df["Salary"]:
    l.append(int(float(i.repalce("k", ""))*1000))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[95], line 3
#       1 l =[]
#       2 for i in df["Salary"]:
# ----> 3     l.append(int(float(i.repalce("k", ""))*1000))
#
# AttributeError: 'int' object has no attribute 'repalce'

# %%
print(l)
# Out:
# []

# %%
df["Salary"] = l
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 df["Salary"] = l
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4672, in DataFrame.__setitem__(self, key, value)
#    4669     self._setitem_array([key], value)
#    4670 else:
#    4671     # set column
# -> 4672     self._set_item(key, value)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4872, in DataFrame._set_item(self, key, value)
#    4862 def _set_item(self, key, value) -> None:
#    4863     """
#    4864     Add series to DataFrame in specified column.
#    4865
#    (...)   4870     ensure homogeneity.
#    4871     """
# -> 4872     value, refs = self._sanitize_column(value)
#    4874     if (
#    4875         key in self.columns
#    4876         and value.ndim == 1
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      10 non-null     int64
#  1   Name    10 non-null     str
#  2   Age     10 non-null     int64
#  3   Dept    10 non-null     str
#  4   Salary  10 non-null     int64
# dtypes: int64(3), str(2)
# memory usage: 630.0 bytes

# %%
# filter 
df[df["Salary"]> 55000]
# Out:
#     Id     Name  Age        Dept  Salary
# 0  101    Rohan   27          IT   72000
# 5  106    rahul   24  Operations   79000
# 6  107    aryan   26          IT  124000
# 7  108    arjun   31       Sales   91000
# 8  109   aditya   28          HR   67000
# 9  110  chandan   33  Operations   70000

# %%
# \ (or) 
df[(df["City"] == "Delhi") | (df["City"] == "Mumbai")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 2
#       1 # \ (or)
# ...

# %%
# & (and) 
df[(df["City"] == "Delhi") & (df["Dept"] == "IT")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 2
#       1 # & (and)
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
di = {
    "ID" : [101,102,103,104,105,106,107,108,109,110,111,112,113,114,115],
    "Name" : ["Rohan" , "Mohit" , "Karan" , "Gaurav" , "Shivam" , "Sahil" , "Kartik" , "Rahul" , "Aryan" , "Aditya" , "Arjun" , "Abhishek" , "Manav" , "Rohit" , "Rishabh"],
    "Age" : [17,19,16,27,np.nan , 24 , np.nan , 19 , np.nan , 25 , 21 , 27 , np.nan , 28 , np.nan],
    "Salary" : [45000 , 84000 ,np.nan , 57000, 60000 , np.nan , 35000 , 74000 , 91000 , np.nan , 55000 , np.nan , 64000 , np.nan , 58000],
    "City"  : ["Delhi" , "Mumbai" , "Pune" , np.nan , "Delhi" , "Kolkata" , "Bangalore" , "Delhi" , np.nan , "Mumbai" , "Delhi" , "Chennai" , "Delhi" , np.nan , "Delhi"],
    "Country" : ["India" , "India" , "India" , "India" , "India" , np.nan , np.nan , "India", np.nan, "India" , "India" , np.nan , "India" , "India" , np.nan]  
}

# %%
df = pd.DataFrame(di)

# %%
df
# Out:
#      ID      Name   Age   Salary       City Country
# 0   101     Rohan  17.0  45000.0      Delhi   India
# 1   102     Mohit  19.0  84000.0     Mumbai   India
# 2   103     Karan  16.0      NaN       Pune   India
# 3   104    Gaurav  27.0  57000.0        NaN   India
# 4   105    Shivam   NaN  60000.0      Delhi   India
# 5   106     Sahil  24.0      NaN    Kolkata     NaN
# 6   107    Kartik   NaN  35000.0  Bangalore     NaN
# 7   108     Rahul  19.0  74000.0      Delhi   India
# 8   109     Aryan   NaN  91000.0        NaN     NaN
# 9   110    Aditya  25.0      NaN     Mumbai   India
# 10  111     Arjun  21.0  55000.0      Delhi   India
# 11  112  Abhishek  27.0      NaN    Chennai     NaN
# 12  113     Manav   NaN  64000.0      Delhi   India
# 13  114     Rohit  28.0      NaN        NaN   India
# 14  115   Rishabh   NaN  58000.0      Delhi     NaN

# %%
df.isnull().sum()
# Out:
# ID         0
# Name       0
# Age        5
# Salary     5
# City       3
# Country    5
# dtype: int64

# %%
# fillna ----> df[col].fillna(value)
df["Country"].fillna("india", inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1548\4006256839.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Country"].fillna("india", inplace = True)
# 0     India
# 1     India
# 2     India
# 3     India
# 4     India
# 5     india
# 6     india
# 7     India
# 8     india
# 9     India
# 10    India
# 11    india
# ...

# %%
df
# Out:
#      ID      Name   Age   Salary       City Country
# 0   101     Rohan  17.0  45000.0      Delhi   India
# 1   102     Mohit  19.0  84000.0     Mumbai   India
# 2   103     Karan  16.0      NaN       Pune   India
# 3   104    Gaurav  27.0  57000.0        NaN   India
# 4   105    Shivam   NaN  60000.0      Delhi   India
# 5   106     Sahil  24.0      NaN    Kolkata     NaN
# 6   107    Kartik   NaN  35000.0  Bangalore     NaN
# 7   108     Rahul  19.0  74000.0      Delhi   India
# 8   109     Aryan   NaN  91000.0        NaN     NaN
# 9   110    Aditya  25.0      NaN     Mumbai   India
# 10  111     Arjun  21.0  55000.0      Delhi   India
# 11  112  Abhishek  27.0      NaN    Chennai     NaN
# 12  113     Manav   NaN  64000.0      Delhi   India
# 13  114     Rohit  28.0      NaN        NaN   India
# 14  115   Rishabh   NaN  58000.0      Delhi     NaN

# %%
df.isnull().sum()
# Out:
# ID         0
# Name       0
# Age        5
# Salary     5
# City       3
# Country    5
# dtype: int64

# %%
df["Age"].fillna(df["Age"].median() , inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1548\3579205347.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Age"].fillna(df["Age"].median() , inplace = True)
# 0     17.0
# 1     19.0
# 2     16.0
# 3     27.0
# 4     22.5
# 5     24.0
# 6     22.5
# 7     19.0
# 8     22.5
# 9     25.0
# 10    21.0
# 11    27.0
# ...

# %%
df
# Out:
#      ID      Name   Age   Salary       City Country
# 0   101     Rohan  17.0  45000.0      Delhi   India
# 1   102     Mohit  19.0  84000.0     Mumbai   India
# 2   103     Karan  16.0      NaN       Pune   India
# 3   104    Gaurav  27.0  57000.0        NaN   India
# 4   105    Shivam   NaN  60000.0      Delhi   India
# 5   106     Sahil  24.0      NaN    Kolkata     NaN
# 6   107    Kartik   NaN  35000.0  Bangalore     NaN
# 7   108     Rahul  19.0  74000.0      Delhi   India
# 8   109     Aryan   NaN  91000.0        NaN     NaN
# 9   110    Aditya  25.0      NaN     Mumbai   India
# 10  111     Arjun  21.0  55000.0      Delhi   India
# 11  112  Abhishek  27.0      NaN    Chennai     NaN
# 12  113     Manav   NaN  64000.0      Delhi   India
# 13  114     Rohit  28.0      NaN        NaN   India
# 14  115   Rishabh   NaN  58000.0      Delhi     NaN

# %%
df.isnull().sum()
# Out:
# ID         0
# Name       0
# Age        5
# Salary     5
# City       3
# Country    5
# dtype: int64

# %%
df["Salary"].fillna(df["Salary"].mean() , inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1548\2444132494.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Salary"].fillna(df["Salary"].mean() , inplace = True)
# 0     45000.0
# 1     84000.0
# 2     62300.0
# 3     57000.0
# 4     60000.0
# 5     62300.0
# 6     35000.0
# 7     74000.0
# 8     91000.0
# ...

# %%
df
# Out:
#      ID      Name   Age   Salary       City Country
# 0   101     Rohan  17.0  45000.0      Delhi   India
# 1   102     Mohit  19.0  84000.0     Mumbai   India
# 2   103     Karan  16.0      NaN       Pune   India
# 3   104    Gaurav  27.0  57000.0        NaN   India
# 4   105    Shivam   NaN  60000.0      Delhi   India
# 5   106     Sahil  24.0      NaN    Kolkata     NaN
# 6   107    Kartik   NaN  35000.0  Bangalore     NaN
# 7   108     Rahul  19.0  74000.0      Delhi   India
# 8   109     Aryan   NaN  91000.0        NaN     NaN
# 9   110    Aditya  25.0      NaN     Mumbai   India
# 10  111     Arjun  21.0  55000.0      Delhi   India
# 11  112  Abhishek  27.0      NaN    Chennai     NaN
# 12  113     Manav   NaN  64000.0      Delhi   India
# 13  114     Rohit  28.0      NaN        NaN   India
# 14  115   Rishabh   NaN  58000.0      Delhi     NaN

# %%
df.isnull().sum()
# Out:
# ID         0
# Name       0
# Age        5
# Salary     5
# City       3
# Country    5
# dtype: int64

# %%
df["City"].mode()
# Out:
# 0    Delhi
# Name: City, dtype: str

# %%
df["City"].fillna("Delhi" , inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1548\3128818157.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["City"].fillna("Delhi" , inplace = True)
# 0         Delhi
# 1        Mumbai
# 2          Pune
# 3         Delhi
# 4         Delhi
# 5       Kolkata
# 6     Bangalore
# 7         Delhi
# 8         Delhi
# ...

# %%
df
# Out:
#      ID      Name   Age   Salary       City Country
# 0   101     Rohan  17.0  45000.0      Delhi   India
# 1   102     Mohit  19.0  84000.0     Mumbai   India
# 2   103     Karan  16.0      NaN       Pune   India
# 3   104    Gaurav  27.0  57000.0        NaN   India
# 4   105    Shivam   NaN  60000.0      Delhi   India
# 5   106     Sahil  24.0      NaN    Kolkata     NaN
# 6   107    Kartik   NaN  35000.0  Bangalore     NaN
# 7   108     Rahul  19.0  74000.0      Delhi   India
# 8   109     Aryan   NaN  91000.0        NaN     NaN
# 9   110    Aditya  25.0      NaN     Mumbai   India
# 10  111     Arjun  21.0  55000.0      Delhi   India
# 11  112  Abhishek  27.0      NaN    Chennai     NaN
# 12  113     Manav   NaN  64000.0      Delhi   India
# 13  114     Rohit  28.0      NaN        NaN   India
# 14  115   Rishabh   NaN  58000.0      Delhi     NaN

# %%
di = {
    "ID" : [101,102,103,104,105,106,107,108,109,110],
    "Product" : ["Iphone" , "Samsung" , "Vivo" , "Oppo" , "Iphone" , "Vivo" , "Samsung" , "Oppo" , "Iphone" , "Oppo"],
    "Price" : [124000 , 48000 , 24000 , 26000 , np.nan , 32000 , 54000 , np.nan , 11500, np.nan]
}

# %%
df = pd.DataFrame(di)
df
# Out:
#     ID  Product     Price
# 0  101   Iphone  124000.0
# 1  102  Samsung   48000.0
# 2  103     Vivo   24000.0
# 3  104     Oppo   26000.0
# 4  105   Iphone       NaN
# 5  106     Vivo   32000.0
# 6  107  Samsung   54000.0
# 7  108     Oppo       NaN
# 8  109   Iphone  115000.0
# 9  110     Oppo       NaN

# %%
ip_mean = df[df["Product"] == "Iphone"]["Price"].mean()
print(ip_mean)
# Out:
# 119500.0

# %%
op_mean = df[df["Product"] =="Oppo"]["Price"].mean()
print(op_mean)
# Out:
# 26000.0

# %%
df["Price"].fillna(0 , Inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df["Price"].fillna(0 , Inplace = True)
#
# TypeError: NDFrame.fillna() got an unexpected keyword argument 'Inplace'. Did you mean 'inplace'?

# %%
l = []
for i , j in zip(df["Product"] , df["Price"]):
    if i == "Iphone" and j == 0:
        l.append(ip_mean)
    if i == "Oppo" and j == 0:
    elif:
        l.append(op_mean)
    elif:
        l.append(j)
# Out:
#   Cell In[34], line 6
#     elif:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 5

# %%
print(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 print(l)
#
# NameError: name 'l' is not defined

# %%
d1 = {
    "emp_id" : [101 , 102 , 103 , 104 , 105],
    "emp_name" : ["Rohan" , "Mohit" , "Yash" , "Keshave" , "Rahul"],
    "emp_age" :[24,29 ,37 ,28, 31],
    "emp_city" :["Delhi" , "Mumbai" , "pune" , "kolata", "Haryana"]
 }

personal = pd.DataFrame(d1)
Personal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 9
#       1 d1 = {
#       2     "emp_id" : [101 , 102 , 103 , 104 , 105],
#       3     "emp_name" : ["Rohan" , "Mohit" , "Yash" , "Keshave" , "Rahul"],
#       4     "emp_age" :[24,29 ,37 ,28, 31],
#       5     "emp_city" :["Delhi" , "Mumbai" , "pune" , "kolata", "Haryana"]
#       6  }
#       8 personal = pd.DataFrame(d1)
# ----> 9 Personal
#
# NameError: name 'Personal' is not defined

# %%
d2 = {
    "emp_id" : [101 , 102 , 103 , 104 , 105],
    "emp_dept" : ["IT" , "Sales" , "HR" , "IT" , "Operaations"],
    "emp_joining" :["2023-05-17" , "2024-06-19", "2025-07-20" , "2026-08-21" , "2026-10-23"],
    "emp_salary" :[68000 , 420000 ,310000, 50000 , 48000]
}

Personal = pd.DataFrame(d2)
Personal
# Out:
#    emp_id     emp_dept emp_joining  emp_salary
# 0     101           IT  2023-05-17       68000
# 1     102        Sales  2024-06-19      420000
# 2     103           HR  2025-07-20      310000
# 3     104           IT  2026-08-21       50000
# 4     105  Operaations  2026-10-23       48000

# %%
# Merage --- pd.Merge(df1 , df2 , on = "Common_column" , how = "type_of_Joine")
pd.merge(Personal , Professional , on = "emp_id" , how = "inner")

# %%
pd.merge(Personal , Professional , on = "emp_id" , how = "right")

# %%
pd.merge(Personal , Professional , on = "emp_id" , how = "Right")

# %%
pd.merge(Personal , Professional , on = "emp_id" , how = "outer")

# %%
import pandas as pd

# %%
df = pd.read_excel(r
