# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in C:\Users\HP\Desktop\shubham\Lib\site-packages (9.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
    host = "Localhost",
    user = "root",
    password = "9667017288",
    database = "comp"
)

# %%
cursor = mydb.cursor()

# %%
cursor.execute("select * from emp")

# %%
cursor.fetchone()
# Out:
# (101, 'ROHAN', 'IT', 55000)

# %%
cursor.fetchall()
# Out:
# [(102, 'MOHIT', 'SALES', 42000),
#  (103, 'MANAV', 'HR', 35000),
#  (104, 'YASH', 'IT', 62000)]

# %%
cursor.fetchmany(2)
# Out:
# [(102, 'MOHIT', 'SALES', 42000)]

# %%
cursor.execute("select * from emp")

# %%
import pandas as pd 
df = pd.DataFrame(cursor)
df
# Out:
#      0      1      2      3
# 0  101  ROHAN     IT  55000
# 1  102  MOHIT  SALES  42000
# 2  103  MANAV     HR  35000
# 3  104   YASH     IT  62000

# %%
col = []
for i in cursor.description:
    col.append(i[0])

# %%
import mysql.connector
