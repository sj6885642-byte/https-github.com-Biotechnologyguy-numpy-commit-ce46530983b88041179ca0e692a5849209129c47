# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\HP\Downloads\Sample - Superstore.xls")
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
la = df[df["City"] == "Los Angeles"]
la
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 6          7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 7          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 8          9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9976    9977  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9977    9978  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9978    9979  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9979    9980  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
#
#      Customer ID    Customer Name      Segment        Country         City  \
# 2       DV-13045  Darrin Van Huff    Corporate  United States  Los Angeles
# ...

# %%
highest = la.groupby("Customer Name")["Sales"].count()
highest.sort_values(ascending = False)[:5]
# Out:
# Customer Name
# Arthur Prichep    10
# Clay Ludtke       10
# Greg Guthrie       9
# William Brown      9
# Arianne Irving     8
# Name: Sales, dtype: int64

# %%
segment = df.groupby("Segment")["Sales"].sum()
print(segment)
# Out:
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64

# %%
state = df.groupby("State")["Sales"].sum()
print(state)
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %%
Customer_Name = df.groupby("Customer_Name")["Sales"].sum()
print(Customer_Name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 Customer_Name = df.groupby("Customer_Name")["Sales"].sum()
#       2 print(Customer_Name)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
# ...

# %%
region_total = df.groupby("Region")["Sales"].sum()
print(region_total)
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
biggest_region = region_total.idxmax()
print(biggest_region)
# Out:
# West

# %%
henderson = df[df["City"] == "Henderson"]
henderson
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 538      539  CA-2015-134894 2015-12-07 2015-12-11  Standard Class
# 539      540  CA-2015-134894 2015-12-07 2015-12-11  Standard Class
# 996      997  CA-2015-162537 2015-10-28 2015-11-03  Standard Class
# 997      998  CA-2015-162537 2015-10-28 2015-11-03  Standard Class
# 998      999  CA-2015-162537 2015-10-28 2015-11-03  Standard Class
# 999     1000  CA-2015-162537 2015-10-28 2015-11-03  Standard Class
# 1866    1867  CA-2017-118857 2017-04-15 2017-04-18     First Class
# 2321    2322  CA-2015-109470 2015-12-31 2016-01-03    Second Class
# 2322    2323  CA-2015-109470 2015-12-31 2016-01-03    Second Class
# 2323    2324  CA-2015-109470 2015-12-31 2016-01-03    Second Class
# 2324    2325  CA-2015-109470 2015-12-31 2016-01-03    Second Class
# ...

# %%
highest = henderson.groupby("Product Name")["Sales"].count()
highest.sort_values(ascending = False)[:5]
# Out:
# Product Name
# Global Adaptabilities Conference Tables                        2
# Magna Visual Magnetic Picture Hangers                          2
# Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back    2
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                        1
# Advantus Panel Wall Certificate Holder - 8.5x11                1
# Name: Sales, dtype: int64

# %%
df.groupby("sub-category"),["Profit"].sum().sort_values(ascending=False).head(3).index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df.groupby("sub-category"),["Profit"].sum().sort_values(ascending=False).head(3).index
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
# ...

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\HP\Downloads\final_dataset.csv")
df
# Out:
#       Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0        1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1        2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2        3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3        4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4        5      1  2021               0     2   54.06   55.54  122.66   9.70
# ...    ...    ...   ...             ...   ...     ...     ...     ...    ...
# 1456    27     12  2024               0     5   58.43  249.17   41.69  65.89
# 1457    28     12  2024               0     6   33.83  150.77   33.31  66.14
# 1458    29     12  2024               1     7   31.21  139.75   27.01  65.94
# 1459    30     12  2024               0     1   38.01  152.83   29.12  65.16
# 1460    31     12  2024               0     2   80.42  318.96   40.37  64.98
#
#         CO  Ozone  AQI
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
df = pd.read_excel(r"C:\Users\HP\Downloads\Forbes_2000_Companies_2025.xlsx")
df.head()
# Out:
#    Rank                                   Company   Headquarters  \
# 0     1                             JPMorganChase  United States
# 1     2                        Berkshire Hathaway  United States
# 2     3                                      ICBC          China
# 3     4  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia
# 4     5                                    Amazon  United States
#
#                Industry  Sales ($B)  Profit ($B)  Assets ($B)  \
# 0               Banking      285.11        59.36      4357.86
# 1             Insurance      371.43        89.00      1153.88
# 2               Banking      221.96        50.84      6688.60
# 3  Oil & Gas Operations      480.15       104.97       645.03
# 4  Retail and Wholesale      637.96        59.25       624.89
#
#    Market Value ($B)
# 0             677.80
# 1            1145.46
# 2             251.33
# 3            1663.38
# 4            2005.64

# %%
col = []
for i in df.columns:
    if" ($B)" in i:
        col.append(i.replace(" ($B)",""))
    else:
        col.append(i)
df.columns = col

# %%
print(col)
# Out:
# ['Rank', 'Company', 'Headquarters', 'Industry', 'Sales', 'Profit', 'Assets', 'Market Value']

# %%
df["profit Margin"] = df["Profit"] / df["Sales"]

# %%
print(df.head())
# Out:
#    Rank                                   Company   Headquarters  \
# 0     1                             JPMorganChase  United States
# 1     2                        Berkshire Hathaway  United States
# 2     3                                      ICBC          China
# 3     4  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia
# 4     5                                    Amazon  United States
#
#                Industry   Sales  Profit   Assets  Market Value  profit Margin
# 0               Banking  285.11   59.36  4357.86        677.80       0.208200
# 1             Insurance  371.43   89.00  1153.88       1145.46       0.239614
# 2               Banking  221.96   50.84  6688.60        251.33       0.229050
# 3  Oil & Gas Operations  480.15  104.97   645.03       1663.38       0.218619
# 4  Retail and Wholesale  637.96   59.25   624.89       2005.64       0.092874

# %%
df["Sales"]
# Out:
# 0       285.110
# 1       371.430
# 2       221.960
# 3       480.150
# 4       637.960
#          ...
# 1995      7.360
# 1996     15.520
# 1997      8.790
# 1998      0.474
# 1999      0.716
# Name: Sales, Length: 2000, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           2000 non-null   int64
#  1   Company        2000 non-null   str
#  2   Headquarters   2000 non-null   str
#  3   Industry       2000 non-null   str
#  4   Sales          2000 non-null   float64
#  5   Profit         1998 non-null   float64
#  6   Assets         2000 non-null   float64
#  7   Market Value   2000 non-null   float64
#  8   profit Margin  1998 non-null   float64
# dtypes: float64(5), int64(1), str(3)
# memory usage: 217.7 KB

# %%
df.isnull().sum()
# Out:
# Rank             0
# Company          0
# Headquarters     0
# Industry         0
# Sales            0
# Profit           2
# Assets           0
# Market Value     0
# profit Margin    2
# dtype: int64

# %%
df["Profit"].fillna(df["Profit"].mean() , inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12896\3510829014.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Profit"].fillna(df["Profit"].mean() , inplace = True)
# 0        59.3600
# 1        89.0000
# 2        50.8400
# 3       104.9700
# 4        59.2500
#           ...
# 1995      0.3781
# 1996      0.0784
# ...

# %%
df
# Out:
#       Rank                                   Company    Headquarters  \
# 0        1                             JPMorganChase   United States
# 1        2                        Berkshire Hathaway   United States
# 2        3                                      ICBC           China
# 3        4  Saudi Arabian Oil Company (Saudi Aramco)    Saudi Arabia
# 4        5                                    Amazon   United States
# ...    ...                                       ...             ...
# 1995  1996                               Dino Polska          Poland
# 1996  1997                        China Aviation Oil       Singapore
# 1997  1998                                      Jet2  United Kingdom
# 1998  1998                                Keiyo Bank           Japan
# 1999  1998                         PT Lippo Karawaci       Indonesia
#
#                           Industry    Sales    Profit   Assets  Market Value  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Rank', 'Company', 'Headquarters', 'Industry', 'Sales', 'Profit',
#        'Assets', 'Market Value', 'profit Margin'],
#       dtype='str')

# %%
l = []
for i in df["profit Margin"]:
    l.append(f"{(i*100)//1}%")
print(l)
# Out:
# ['20.0%', '23.0%', '22.0%', '21.0%', '9.0%', '14.0%', '23.0%', '19.0%', '30.0%', '35.0%', '24.0%', '18.0%', '9.0%', '10.0%', '15.0%', '16.0%', '5.0%', '2.0%', '11.0%', '12.0%', '37.0%', '7.0%', '5.0%', '14.0%', '6.0%', '13.0%', '11.0%', '5.0%', '9.0%', '9.0%', '13.0%', '13.0%', '12.0%', '15.0%', '9.0%', '7.0%', '29.0%', '41.0%', '29.0%', '9.0%', '8.0%', '24.0%', '12.0%', '7.0%', '7.0%', '7.0%', '55.0%', '11.0%', '14.0%', '13.0%', '1.0%', '11.0%', '15.0%', '3.0%', '12.0%', '13.0%', '16.0%', '8.0%', '14.0%', '18.0%', '16.0%', '12.0%', '14.0%', '5.0%', '6.0%', '21.0%', '9.0%', '18.0%', '6.0%', '6.0%', '6.0%', '7.0%', '12.0%', '1.0%', '18.0%', '27.0%', '15.0%', '8.0%', '8.0%', '13.0%', '5.0%', '12.0%', '4.0%', '10.0%', '33.0%', '10.0%', '5.0%', '9.0%', '26.0%', '9.0%', '5.0%', '9.0%', '2.0%', '16.0%', '8.0%', '11.0%', '5.0%', '3.0%', '7.0%', '23.0%', '7.0%', '8.0%', '3.0%', '22.0%', '16.0%', '8.0%', '8.0%', '7.0%', '13.0%', '15.0%', '17.0%', '12.0%', '28.0%', '4.0%', '17.0%', '38.0%', '4
# ...

# %%
df["Profit Margin"] = l

# %%
df.head()
# Out:
#    Rank                                   Company   Headquarters  \
# 0     1                             JPMorganChase  United States
# 1     2                        Berkshire Hathaway  United States
# 2     3                                      ICBC          China
# 3     4  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia
# 4     5                                    Amazon  United States
#
#                Industry   Sales  Profit   Assets  Market Value  profit Margin  \
# 0               Banking  285.11   59.36  4357.86        677.80       0.208200
# 1             Insurance  371.43   89.00  1153.88       1145.46       0.239614
# 2               Banking  221.96   50.84  6688.60        251.33       0.229050
# 3  Oil & Gas Operations  480.15  104.97   645.03       1663.38       0.218619
# 4  Retail and Wholesale  637.96   59.25   624.89       2005.64       0.092874
#
#   Profit Margin
# 0         20.0%
# 1         23.0%
# 2         22.0%
# 3         21.0%
# 4          9.0%

# %%
north_america = []
south_america = []
asia = []
europe = []
middle_east = []
australia = []

for i in country:
    if i in ["Canada","Colombia" , "United States" , "Chile"]:
        north_america.append(i)
    elif i in ["Brazil","Argentina" , "Mexico"]:
         south_america.append(i)
    elif i in ["China" , "India" ,"Hong Kong" , "Indonesiya" , "Malaysia","Singapore" , "South Korea" , "Taiwan" , "Thailand" , "Vietnam"]:
        asia.append(i)
    elif i in ["Czech Republic" , "Israel" , "Kazakhstan" , "Kuwait" , "Qatar" , "Saudi Arabia"]:
        Middle_east.append(i)
    elif i in ["Australia"]:
        australia.append(i)
    else:
        eurpoe.append(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 8
#       5 middle_east = []
#       6 australia = []
# ----> 8 for i in country:
#       9     if i in ["Canada","Colombia" , "United States" , "Chile"]:
#      10         north_america.append(i)
#
# NameError: name 'country' is not defined

# %%
region  = []
for i in df["Headquarters"]:
     if i in north_america:
         region.append("North America")
     elif i in south_america:
         region.append("South Amrica")
     elif i in asia:
         region.append(Asia)
     elif i in middle_east:
         region.append("Middle_east")
     elif i in australia:
         region.append("Austraia")
     elif i in europe:
         region.append("Europe")

# %%
df["region"] = region

# %%
df

# %%
for i , j in enumerate(df["Sales"]):
    if j == 0:
        print(i)
# Out:
# 1820

# %%
df.loc[1820 , "sales"] = 1

# %%
df["MV/Sales Ratio"] = df["Market Value"] / df["Sales"]
df
# Out:
#       Rank                                   Company    Headquarters  \
# 0        1                             JPMorganChase   United States
# 1        2                        Berkshire Hathaway   United States
# 2        3                                      ICBC           China
# 3        4  Saudi Arabian Oil Company (Saudi Aramco)    Saudi Arabia
# 4        5                                    Amazon   United States
# ...    ...                                       ...             ...
# 1995  1996                               Dino Polska          Poland
# 1996  1997                        China Aviation Oil       Singapore
# 1997  1998                                      Jet2  United Kingdom
# 1998  1998                                Keiyo Bank           Japan
# 1999  1998                         PT Lippo Karawaci       Indonesia
#
#                           Industry    Sales    Profit   Assets  Market Value  \
# ...

# %%
company = df.groupby("Company")['MV/Sales Ratio'].sum()
company.sort_values(ascending = False)[:5].plot(kind = "bar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 company = df.groupby("Company")['MV/Sales Ratio'].sum()
#       2 company.sort_values(ascending = False)[:5].plot(kind = "bar")
#
# NameError: name 'df' is not defined

# %%
industry = df.groupby("Industry")['MV/Sales Ratio'].mean()
industry.sort_values(ascending = False).head(5).plot(Kind = "bar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 industry = df.groupby("Industry")['MV/Sales Ratio'].mean()
#       2 industry.sort_values(ascending = False).head(5).plot(Kind = "bar")
#
# NameError: name 'df' is not defined
