# %% [markdown]
# # Nested Dictionaries
# # Dictionary Method :-
# A dictionary can contain dictionaries, this is called nested dictionaries.

# %% [markdown]
# 1. Add Method ----- var[key] = value  -----:-is used to add a new element to a set .
#
# 2. Update/modifying Method ---- var.update(dict) ------:-it may be the process used to update a device or application to the latest version, or it may be the act of adding or modifying information to a data structure (such as a Python dictionary) in a programming context .
#
# 3. Access Method ---- var[key] -----:-are techniques that help the operating system and applications organize, read, and write data stored on a storage device .
#
# 4. Get Method ---- var.get(key)
# 5. Pop Method ----- var.pop(key)------:-you can remove an element from a list or dictionary and also get back that removed element .
# 6. Items Method ---- var.items()
# 7. Key Method ----- var.keys()
# 8. Value Meyhod ----- var.values()
# 9. empty_dict {} ----- var = dict()
#
# a = {}
# a = dict()
# print(a)                                                                                       output {}

# %%
1. # add Method :-
add = {"langauge1" : "pthon",
       "lamgauge2" : "java",
       "langauge3" : "HTML"}
print(add)
# Out:
# {'langauge1': 'pthon', 'lamgauge2': 'java', 'langauge3': 'HTML'}

# %%
add["langauge4"] = "javascript"

# %%
print(add)
# Out:
# {'langauge1': 'pthon', 'lamgauge2': 'java', 'langauge3': 'HTML', 'langauge4': 'javascript'}

# %%
2.# add method :-
add = {"rohit" : "shrama",
           "virat" : "kohli",
           "shubhman" : "gill"}

print(add)
# Out:
# {'rohit': 'shrama', 'virat': 'kohli', 'shubhman': 'gill'}

# %%
add["kl"] = "rahul"

# %%
print(add)
# Out:
# {'rohit': 'shrama', 'virat': 'kohli', 'shubhman': 'gill', 'kl': 'rahul'}

# %%
3. # pop method --- and , add method. to Replace method... use ho rhaa hai.
a = {"Rohit" : "sharma",
     "Virat" : "kohli",
     "Shubhman" : "gill",
     "kl" : "rahul"}
print(a)
# Out:
# {'Rohit': 'sharma', 'Virat': 'kohli', 'Shubhman': 'gill', 'kl': 'rahul'}

# %%
# pop method :- use
a.pop("kl")   # ye hai add method ---- kyoki ham new_value add kr rahe hai
print(a)                  # add method ---- var[key] = new_value
# Out:
# {'Rohit': 'sharma', 'Virat': 'kohli', 'Shubhman': 'gill'}

# %%
# add method :-use
a["jasprit"]  = "bumrah"     # ye hai add method ---- kyoki ham new_value add kr rahe hai                 
                            # add method ---- var[key] = new_value
print(a)
# Out:
# {'Rohit': 'sharma', 'Virat': 'kohli', 'Shubhman': 'gill', 'jasprit': 'bumrah'}

# %%
4.# replace method :- add method :-
a = {
    "sport1" : "cricket",
    "sport2" : "fotboll",
    "sport3" : "badminton",
    "sport4" : "golf"
    
    
}

print(a)
# Out:
# {'sport1': 'cricket', 'sport2': 'fotboll', 'sport3': 'badminton', 'sport4': 'golf'}

# %%
a["sport2"] = "tennis"

# %%
print(a)
# Out:
# {'sport1': 'cricket', 'sport2': 'tennis', 'sport3': 'badminton', 'sport4': 'golf'}

# %%
5. # updat method :-
a = {
    "country1" : "india",
    "country2" : "america",
    "country3" : "england",
    

    
}

print(a)
# Out:
# {'country1': 'india', 'country2': 'america', 'country3': 'england'}

# %%
a.update({"country4" : "japan"})

# %%
print(a)
# Out:
# {'country1': 'india', 'country2': 'america', 'country3': 'england', 'country4': 'japan'}

# %%
6.#remove method :-   pop method :-
a = {
    "country1" : "india",
    "country2" : "america",
    "country3" : "englang",
    "country4" : "japan",
   
    
}

print(a)

a.pop("country2")

# %%
print(a)
# Out:
# {'country1': 'india', 'country3': 'englang', 'country4': 'japan'}

# %%
7. # queston Show all the output from dictionary
a = {
    "sport1" : "cricket",
    "sport2" : "football",
    "sport3" : "badminton",
    "sport4" : "golf",
 
    
}

print(a)
# Out:
# {'sport1': 'cricket', 'sport2': 'football', 'sport3': 'badminton', 'sport4': 'golf'}

# %%
8.# keys value method :-
a = {
    "sport1" : "cricket",
    "sport2" : "football",
    "sport3" : "badminton",
    "sport4" : "golf",
 
    
}

print(a)
# Out:
# {'sport1': 'cricket', 'sport2': 'football', 'sport3': 'badminton', 'sport4': 'golf'}

# %%
print(a.keys())
# Out:
# dict_keys(['sport1', 'sport2', 'sport3', 'sport4'])

# %%
print(a.values())
# Out:
# dict_values(['cricket', 'football', 'badminton', 'golf'])

# %%
9.# value method :-
a = {                                         
    "Rohit" : "sharma",
    "virat" : "kohli",
    "shubhman" : "gill",
    "kl" : "rahul"
    
}

print(a)
# Out:
# {'Rohit': 'sharma', 'virat': 'kohli', 'shubhman': 'gill', 'kl': 'rahul'}

# %%
print(a.keys())
# Out:
# dict_keys(['Rohit', 'virat', 'shubhman', 'kl'])

# %%
print(a.values())
# Out:
# dict_values(['sharma', 'kohli', 'gill', 'rahul'])

# %% [markdown]
# ==================================================
# ==================================================

# %% [markdown]
# # Operator Method :-

# %% [markdown]
# 1. Arithmetic Operator
# 2. Assingnment Operator
# 3. Comparison Operator
# 4. Logical Operator
# 5. Membership Operator
# 6. Identity Operator

# %%
# Arithmetic Operator --- +,-,/,*,//,%,**
print(10+5)
# Out:
# 15

# %%
print(10-5)
print(10*5)
print(10/5)
# Out:
# 5
# 50
# 2.0

# %%
# Floor Division --- //
print(10//3)
print(14//5)
# Out:
# 3
# 2

# %%
# Modulus ---- %
print(10%3)
# Out:
# 1

# %%
# Power---- **
print(5**2)
print(6**2)
# Out:
# 25
# 36

# %%
print(5**3)
# Out:
# 125

# %%
# Assingnment operator --- =,+=,-=,/= .........and so on
a = 10
print(a)
# Out:
# 10

# %%
a+=5  # a = a+5
print(a)
# Out:
# 15

# %%
a+=10
print(a)
# Out:
# 25

# %%
a+=20
print(a)
# Out:
# 45

# %%
a-=5
print(a)
# Out:
# 40

# %%
a*=2
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a*=2
#       2 print(a)
#
# NameError: name 'a' is not defined

# %%
a/=4
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a/=4
#       2 print(a)
#
# NameError: name 'a' is not defined

# %%
# Comparison operator ----- == , !=,>,< , >=,<=
print(10==10)
# Out:
# True

# %%
print(1!=1)
# Out:
# False

# %%
print(1>5)
# Out:
# False

# %%
print(9>=9)
# Out:
# True

# %%
print(90<2)
# Out:
# False

# %%
print(88>9)
# Out:
# True

# %%
a =[10,20,30,40,50]
print(10 in a)
# Out:
# True

# %%
a = {10,20,30,40,50,}
print(10 in a)
# Out:
# True

# %%
a = (10,20,30,40,50)
print(10 in a)
# Out:
# True

# %%
a = 10
print(a>5 and a>7)
# Out:
# True

# %%
a = 10
print(a>5 and a==1)
# Out:
# False

# %%
print(10!=5)
# Out:
# True

# %%
print(10>5)
# Out:
# True

# %%
print(10<15)
# Out:
# True

# %%
# Membership operator --- in ,not ,in
a = [10,20,30,40,50,]
print(20 in a)
# Out:
# True

# %%
print(70 not in a)
# Out:
# True

# %%
gym = ["rohan" , "mohan", "karan" , "gourav"]
print("rohan" in gym)
# Out:
# True

# %%
print("arjun" in gym)
# Out:
# False

# %%
# logical operator --- and or 
a = 10
print(a>5 and a<15)
# Out:
# True

# %%
a = 10
print(a==5 or a<15)
# Out:
# True

# %%
# identity operator --- is , is not
a = 10 
b = 10
print(a is b)
# Out:
# True

# %%
c = 5 
print(a is not c)
# Out:
# True

# %%
https://www.geeksforgeeks.org/
python Corse web site

# %% [markdown]
# # Conditionals Statement

# %%
a = int(input("Enter Number : "))
if a>10:
    print("greater!")
else:
    print("Smaller!")
# Out:
# Enter Number :  14
# greater!

# %%
num = int(input("Enter Number : "))
if num%2==0:
    print("Even!")
else:
    print("odd!")
# Out:
# Enter Number :  12
# Even!

# %%
name = input("Enter Your Name : ")
gym = ["Rohan","rohit","mohit","yash","manav","gaurav"]

if name in gym:
    print("member!")
else:
    print("Not a Member!")
# Out:
# Enter Your Name :  rohan
# Not a Member!

# %%
# a = int(input("enter number : "))
if a>0:
    print("positive")
else:
    print("negative")
# Out:
# enter number :  15
# positive

# %%
num = int(input("Enter Number : "))
if num%5==0:
    print("number!")
else:
    print("input , number")
# Out:
# Enter Number :  50
# number!

# %% [markdown]
# # Conditional Statement Assignment-2 Test:

# %%
num = int(input("Enter a number: "))
if num < 0:
    print("Nagative")
else:
    print("Not Negative")
# Out:
# Enter a number:  5
# Not Negative

# %%
num = int(input("Calculates the Square of Number: "))
if num *12:
    print("Square of number")
else:
    print("Input number")
# Out:
# Calculates the Square of Number:  24
# Square of number

# %%
Name = input("Enter Your Name: ")
if len(Name) > 10:
    print("long Name")
else:
    print("short Name")
# Out:
# Enter Your Name:  shubham
# short Name

# %%
user_input = int(input("Enter a number: "))
if user_input:
    print("Integer")
else:
    print("Not Integer")
# Out:
# Enter a number:  50
# Integer

# %%
a = input("Enter a string")
if "python" not in a:
    print("contains python")
else:
    print("Does not contain python")
# Out:
# Enter a string python
# Does not contain python

# %%
number_1 = input("Enter First number:")
number_2 = input("Enter second number:")
if number
