# %%
num_put = int(input("Enter a possitive number: "))
if num_put > 10:
    print("positive")
else:
    print("not positive")
# Out:
# Enter a possitive number:  -50
# not positive

# %%
num_put = int(input("Enter a number: "))
if num_put%4==0:
    print("Even!")
else:
    print("Odd!")
# Out:
# Enter a number:  50
# Odd!

# %%
Age_put = int(input("Enter Your Age : "))
if Age_put >= 18:
    print("You are eligible to vote: ")
else:
    print("You are not eligible to vote: ")
# Out:
# Enter Your Age :  17
# You are not eligible to vote:

# %%
num_put = int(input("Enter Your Age : "))
if num_put%5==0:
    print("Divisible by 5!")
else:
    print("Not Divisible by 5! ")
# Out:
# Enter Your Age :  66
# Not Divisible by 5!

# %%
a = input("Enter a chake number: ")
if a in ('a','e','i','o','u'):
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a chake number:  i
# Vowel

# %%
Age = int(input("Enter the age Category: "))
if 0 <= Age <= 12:
    print("Child")
elif 13 <= Age <= 19:
    print("Teeneger")
else:
    print("Other age")
# Out:
# Enter the age Category:  35
# Other age

# %%
num_put = int(input("Enter a Number: "))
if num_put > 100:
    print("greater than 100")
elif num_put < 100:
    print("Less than 100")
else:
    print("Euual to 100")
# Out:
# Enter a Number:  150
# greater than 100

# %%
num_put = int(input("Enter a number: "))
if num_put > 0:
    print("Positive")
elif num_put < 0:
    print("Negative")
else:
    print("zero")
# Out:
# Enter a number:  -199
# Negative

# %%
lenth = input("Enter the length of rectangale: ")
width = input("Enter the width of rectangale: ")
if lenth <= 0:
    print("length of less than equal to 0")
elif width <= 0:
    print("width of less than equal to 0")
else:
    area = lenth*width
    print("lenth or width equal to 0 area")
# Out:
# Enter the length of rectangale:  5
# Enter the width of rectangale:  7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 lenth = input("Enter the length of rectangale: ")
#       2 width = input("Enter the width of rectangale: ")
# ----> 3 if lenth <= 0:
#       4     print("length of less than equal to 0")
#       5 elif width <= 0:
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %% [markdown]
# # pracketish

# %%
num_put = int(input("Enter a number: "))
if num_put%4==0:
    print("Even!")
else:
    print("Odd!")
# Out:
# Enter a number:  12
# Even!

# %%
marks = int(input("Enter Marks: "))
if marks >= 90 and marks <= 100:
    print("grade a!")
elif marks >= 80 and marks < 89:
    print("grade b!")
elif marks >= 70 and marks < 79:
    print("grade c!")
elif marks >= 60 and marks < 69:
    print("grade d!")
elif marks >= 0 and marks < 60:
    print("faill")
else:
    print("please Enter a valid marks!")
# Out:
# Enter Marks:  67
# grade d!

# %%
num_put = int(input("Enter a number"))
if num_put > 3:
    print("the largest one")
# Out:
# Enter a number 4
# the largest one

# %%
Year_put = int(input("Enter the leap year: "))
if (Year_put %4 == 0 or Year % 400 == 0):
    print("Leep year")
elif (Year_put and Year % 100 != 0):
    print("4 but not by 100")
else:
    print("Not Leep Year")
# Out:
# Enter the leap year:  400
# Leep year

# %%
num = int(input("Enter a number: "))
if num < 0:
    print("Nagative")
else:
    print("Positive")
# Out:
# Enter a number:  -4
# Nagative

# %%
age = int(input("Enter a age category:"))
if 0 <= age <= 12:
    print("Child")
elif 13 <= age <= 19:
    print("Teen")
elif 20 <= age <= 59:
    print("Adult")
else:
    print(60 and above)
# Out:
# Enter a age category: 45
# Adult

# %%
pass_key = input("Enter the password: ")
if pass_key == "OpenAi123":
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Enter the password:  OpenAi123
# Access Granted

# %%
Num = int(input("Enter a number: "))
if num % 3 == 0 and num % 5 == 0:
    print("Divisible by 3 and 5' if true")
elif num % 3 == 0:
    print("Divisibale by 3")
elif num % 5 == 0:
    print("Divisibale by 5")
else:
    print("not Divisibal by 3 or 5")
# Out:
# Enter a number:  23
# not Divisibal by 3 or 5

# %%
a = input("Enter First Sid: ")
b = input("Enter Second Side: ")
c = input("Enter Third Side: ")
if a == b == c:
    print("Equilateral if all side sre equal")
elif a == b or b == c or a == c:
    print("isosceles if any two sides are equal")
else:
    print("Scalene if all sides are different")
# Out:
# Enter First Sid:  5
# Enter Second Side:  5
# Enter Third Side:  5
# Equilateral if all side sre equal

# %% [markdown]
# # ====================================
