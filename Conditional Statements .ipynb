# %% [markdown]
# # Conditionals Statement

# %%
a = int(input("Enter Number : "))
if a>10:
    print("greater!")
else:
    print("Smaller!")
# Out:
# Enter Number :  14
# greater!

# %%
num = int(input("Enter Number : "))
if num%2==0:
    print("Even!")
else:
    print("odd!")
# Out:
# Enter Number :  12
# Even!

# %%
name = input("Enter Your Name : ")
gym = ["Rohan","rohit","mohit","yash","manav","gaurav"]

if name in gym:
    print("member!")
else:
    print("Not a Member!")
# Out:
# Enter Your Name :  rohan
# Not a Member!

# %%
# a = int(input("enter number : "))
if a>0:
    print("positive")
else:
    print("negative")
# Out:
# positive

# %%
num = int(input("Enter Number : "))
if num%5==0:
    print("number!")
else:
    print("input , number")
# Out:
# Enter Number :  50
# number!

# %%
num = int(input("Enter a number: "))
if num < 0:
    print("Negative")
else:
    print("Not Negative")
# Out:
# Enter a number:  5
# Not Negative

# %%
num = int(input("Enter a number: "))
print(num**2)
# Out:
# Enter a number:  5
# 25

# %% [markdown]
# # ===============================================

# %% [markdown]
# # Conditional Statement Assignment-2 Test

# %%
num = int(input("Enter a number: "))
if num < 0:
    print("Nagative")
else:
    print("Not Negative")
# Out:
# Enter a number:  5
# Not Negative

# %%
num = int(input("Calculates the Square of Number: "))
if num *12:
    print("Square of number")
else:
    print("Input number")
# Out:
# Calculates the Square of Number:  24
# Square of number

# %%
Name = input("Enter Your Name: ")
if len(Name) > 10:
    print("long Name")
else:
    print("short Name")
# Out:
# Enter Your Name:  shubham
# short Name

# %%
user_input = int(input("Enter a number: "))
if user_input:
    print("Integer")
else:
    print("Not Integer")
# Out:
# Enter a number:  50
# Integer

# %%
a = input("Enter a string")
if "python" not in a:
    print("contains python")
else:
    print("Does not contain python")
# Out:
# Enter a string python
# Does not contain python

# %%
# if stetment :-
# if stetment works only for true condition # :- ye stetment jabhi kaam krega jab uska condition true hoga
a = 260
b = 108                        # warna abhi ye fale show kar rhaa hai
if b > a:
    print("b is grater then a")

# %%
age = int(input("Enter your age"))
if age > 19:
    print("you are an adult")
# Out:
# Enter your age 21
# you are an adult

# %%
# 2.if stetment :-
age  = int(input("Enter Your age"))
if age > 19:
           print("You are an adult")
else:
    print("You are not adult")
# Out:
# Enter Your age 18
# You are not adult

# %%
temp = 30
if temp < 25:
    print("It's a cool day")
else:
    print("It's a hot day")
# Out:
# It's a hot day

# %%
tempechar = int(input("how is the weather"))
temp = 30
if temp < 25:
    print("It's a cool day")
else:
    print("It's a hoot day")
# Out:
# how is the weather 15
# It's a hoot day

# %%
# 3. if-elif-else' Conditional Stetment :-
Marks  = int(input("Enter Your Marks-100"))

if Marks >= 90:
    print("grade - A+")
elif Marks >= 80:
    print("garde - A")
elif Marks >= 70:
    print("grade - B")
else:
    print("grade - D")
# Out:
# Enter Your Marks-100 77
# grade - B

# %%
marks = int(input("Enter Marks: "))
if marks >= 90 and marks <= 100:
    print("grade a!")
elif marks >= 75 and marks < 90:
    print("grade b!")
elif marks >= 60 and marks < 75:
    print("grade c!")
elif marks >= 35 and marks < 60:
    print("grade d!")
elif marks >= 0 and marks < 35:
    print("faill")
else:
    print("please Enter a valid marks!")
# Out:
# Enter Marks:  66
# grade c!
