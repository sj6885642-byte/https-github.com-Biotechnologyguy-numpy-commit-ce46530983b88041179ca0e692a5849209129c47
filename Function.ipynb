# %% [markdown]
# # Function in python :-
# Block of statements that perform a specific task.

# %% [markdown]
# a = 5
# b = 20
# sum =  a + b
# print(sum)

# %% [markdown]
# a = 2
# b = 10
# sum = a+b
# print(sum)

# %% [markdown]
# a = 12
# b = 10
# sum = a+b
# print(sum)

# %%
1. # firsst step :- and yisko ham khege ,,[ function . definetion ]
def calc_sum(a,b):   # ---> yise ham khege parameters
    sum = a+b
    return sum

# %%
calc_sum(10,20)
# Out:
# 30

# %%
calc_sum(12,10)
# Out:
# 22

# %%
calc_sum(17, 10)
# Out:
# 27

# %%
2.
def calc_sum(a , b): # sccond step:-
    return a+b

# %%
sum = calc_sum(3,1) # ----> yise ham khege ,, function call ; arguments

# %%
print(sum)
# Out:
# 4

# %%
3.
def print_hallo():
    print("hallo")

# %%
print_hallo()
print_hallo()
print_hallo()
print_hallo()
# Out:
# hallo
# hallo
# hallo
# hallo

# %%
4.
def print_hallo():
    print("hallo")

# %%
sum = print_hallo()
print(sum)
# Out:
# hallo
# None

# %%
5.
def print_hallo():
    print("hallo")

# %%
output = print_hallo()
print(output)
# Out:
# hallo
# None

# %%
6. # average of 3 numbers
def calc_avg(a,b,c):
    sum = a+b+c
    avg = sum /3
    print(avg)
    return avg

# %%
calc_avg(67, 89,90)
# Out:
# 82.0
# 82.0

# %%
def calc_avg(a,b,c):
    sum = a+b+c
    avg = sum /3
    print(avg)
    return avg

# %%
calc_avg(55,68,73)
# Out:
# 65.33333333333333
# 65.33333333333333

# %% [markdown]
# # Function types :- thear are two types of Fuction
# 1. Built-in Function    1,print()   2,len()    3,type()    4,range()
# 2. user defined Function

# %%
1. print() :-function
print("apnacollege","shubhamsharma")
# Out:
# apnacollege shubhamsharma

# %%
print("shubhamsharma")
# Out:
# shubhamsharma

# %%
print("apnacollege", end =" $")
# Out:
# apnacollege $

# %%
print("apnacollege",end = " shubham")
# Out:
# apnacollege shubham

# %%
class MyCustomObject:
    def __init__(self, data):
        self.data = data

    def __len__(self):
        return len(self.data) # Define what "length" means for your object

my_object = MyCustomObject([1, 2, 3])
print(f"Length of custom object: {len(my_object)}") # Output: Length of custom object: 3
# Out:
# Length of custom object: 3

# %%
def cal_prod(a,b=6):
    print(a * b)
    return a * b

# %%
cal_prod(1)
# Out:
# 6
# 6

# %%
cities = ["dekhi","gurgaon","noida","pune","mombi","chennai"]
def print_len(list):
    print(len(cities))

# %%
print(cities)
# Out:
# ['dekhi', 'gurgaon', 'noida', 'pune', 'mombi', 'chennai']

# %%
cities = ["dekhi","gurgaon","noida","pune","mimbi","chennai"]
heroes = ["thor","ironman","captaion america","shaktiman"]
def print_len(list):
    print(len(list))
    
print_len(cities)
print_len(heroes)
# Out:
# 6
# 4

# %%
cities = ["delhi","gurgaon","noida","pune","mimbi","chennai"]
her_oes = ["thor","ironman","captaion america","shaktiman"]

def print_len(list):
    print(len(list))

def print_list(list):
    for item in list :
        print(item, end="\n ")

# %%
print_list(cities)
print_list(her_oes)
print()
# Out:
# delhi
#  gurgaon
#  noida
#  pune
#  mimbi
#  chennai
#  thor
#  ironman
#  captaion america
#  shaktiman

# %%
n =5                             # factorial of n. (n is the parameter)
fact = 1
for i in range(1, n+1):
    fact *= i
print(fact)
# Out:
# 120

# %%
def cal_fact(n):
    fact = 1
    for i in range (1, n+1):
        fact*=i
    print(fact)

# %%
cal_fact(6)
# Out:
# 720

# %%
def cal_fact(n):
    fact = 1
    for i in range (1 , n+1):
        fact *= i
    print(fact)
cal_fact(8)
# Out:
# 40320

# %%
def converter(usd_val):
    inr_val = usd_val * 83
    print(usd_val, "USD =", inr_val, "INR")
converter(10000)
# Out:
# 10000 USD = 830000 INR

# %%
def sum_number(a , b):
    for i in range(10 + 20):
        num += i
sum_numbe = (10+20)
print(sum_number())
# Out:
# <function sum_number at 0x0000011B7DFB82C0>

# %%
def sum_number(a, b):
    return a+b
sum = sum_number(20,30)
print(sum)
# Out:
# 50

# %% [markdown]
# # test :- Function

# %%
def reverse_string(a):
    return a[::-1]

text = input("Enter a string:")
print("return_string:",reverse_string(text))
# Out:
# Enter a string: 34
# return_string: 43

# %%
def count_vowels(a):
    vowels = "aeiou"
    count = 0
    for ch in vowels:
        count+=1
    return count
string = input("Enter a string:")
print("vowels count:",count_vowels(string))
# Out:
# Enter a string: vowels
# vowels count: 5

# %%
def is_prime(num):
    status = "prime"
        for i in range(2,num):
            if n % i == 0:
                return false
            return true
print(prime(6))
# Out:
# not prime

# %%
def prime (num):
    status = "prime"
    for i in range(2, num):
        if num%i==0:
            status = "not prime"
    return status

# %%
print(prime(7))
# Out:
# prime

# %%
def largest_Element(list):
    return max (list)
print(largest_Element([1,3,6,8,12,16,19,20]))
# Out:
# 20

# %%
def remove_duplicates(list):
    return(list)
print(remove_duplicates([1,22,3,4,56,22,5,6]))
# Out:
# [1, 22, 3, 4, 56, 22, 5, 6]

# %%
a = int(input("Enter a number1 :"))
b = int(input("Enter a number2 :"))
print(a/b)
# Out:
# Enter a number1 : 5
# Enter a number2 : 8
# 0.625

# %%
try: 
    cod (if code has not any error / exception)
exception

# %%
try:
    a = int(input("Enter a number1 :"))
    b = int(input("Enter a number2 :"))
    print(a/b)
except zeroDivisionError:
    print("cannot divide by zero!")

except value

    print("cannot divide by zero!")
print("code still running!")
# Out:
#   Cell In[16], line 4
#     except zeroDivisionError:
#     ^
# SyntaxError: invalid syntax

# %%
try :
    a = int(input("Enter a number1 :"))
    b = int(input("Enter a number2 :"))
    print(num1/b)
except Exception as e:
    print(e)

print("code Ended!")
# Out:
# Enter a number1 : 5
# Enter a number2 : 0
# name 'num1' is not defined
# code Ended!

# %%
print("code starting!")
raise zerodivisionerror("hallo myself harsh khann")
print("code error")
# Out:
# code starting!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 print("code starting!")
# ----> 2 raise zerodivisionerror("hallo myself harsh khann")
#       3 print("code error")
#
# NameError: name 'zerodivisionerror' is not defined

# %%
maths = int(input("Enter marks:"))
if maths>=0 and maths<=100:
    science>=0 and science<=100:
       eng = int(input("Enter marks :"))
else:
    raise value Error("science marks should grater than 0 or less than 100")
else:
    raise value Error("maths marks sh")

# %% [markdown]
# # oops

# %%
a = [10,20,30,40,50]
print(type(a))
# Out:
# <class 'list'>

# %% [markdown]
# claas classname:
#     def _init_(self, parameters):
#         code
#     def func1(self , parameter):
#         code
#     def func2(self, parameter):
#         code

# %%
class Employee:
    def __init__(self , Emp_id , name , dept):
        self.Emp_id = Emp_id
        self.name = name
        self.dept =  dept

    def show_info(self):
        return f"Employee ID : {self. Emp_id}\nEmployee name : {self.name}\nEmployee Department: {self.dept}"

# %%
a = Employee(101 , "Rohan", "IT")

# %%
print(type(a))
# Out:
# <class '__main__.Employee'>

# %%
print(a.show_info())
# Out:
# Employee ID : 101
# Employee name : Rohan
# Employee Department: IT

# %%
class car:
    def __init__(company , model , color , price , speed):
        self.compny =  compny
        self.model = model
        self.color = color
        self.price = price
        self.speed = speed

    def de
